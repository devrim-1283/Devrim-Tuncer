# %%
import cv2
import numpy as np

# %%
circle = np.zeros((512,512,3),dtype="uint8") + 255
cv2.circle(circle,(256,256),60,(255,0,0),-1)

rectangular= np.zeros((512,512,3),dtype="uint8") + 255
cv2.rectangle(rectangular,(100,100),(200,300),(0,255,0),thickness=-1)

new_page = cv2.add(circle,rectangular)

cv2.imshow("Circle",new_page)
cv2.waitKey(0)
cv2.destroyAllWindows()

# renk topluyor sadece neden var anlamadım
# Out:
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# ...

# %%
#f(x,y) =x*a + y*b +c 
#Ağırlıklı toplama

circle = np.zeros((512,512,3),dtype="uint8") + 255
cv2.circle(circle,(256,256),30,(255,0,0),-1)

rectangular = np.zeros((512,512,3),dtype="uint8") + 255
cv2.rectangle(rectangular,(200,200),(300,300),(0,255,0),-1)


add2 = cv2.addWeighted(circle,0.7,rectangular,0.3,0)

cv2.imshow("Add 2",add2)
cv2.waitKey(0)


cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# QObject::moveToThread: Current thread (0x4095f540) is not the object's thread (0x403ea800).
# Cannot move to target thread (0x4095f540)
#
# ...

# %%
import numpy as np
import cv2
circle = np.zeros((512,512,3),dtype="uint8") + 255
cv2.circle(circle,(256,256),40,(0,0,255),-1)

rectangular = np.zeros((512,512,3),dtype="uint8") + 255
cv2.rectangle(rectangular,(250,250),(400,400),(0,255,0),-1)

add = cv2.addWeighted(rectangular,0.3,circle,0.3,0)

cv2.imshow("Add Weighted",add)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# ...

# %%
# Renk Uzayları RGB BGR HSV GRAY Renk Uzayı değiştirme

import cv2


img = cv2.imread("test_image/foto1.jpeg")


cv2.imshow("Image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# ...

# %%
img = cv2.imread("test_image/foto1.jpeg")

img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)



cv2.imshow("Img",img)
cv2.imshow("Img RGB",img_rgb)
cv2.imshow("Img HSV",img_hsv)
cv2.imshow("Img Gray",img_gray)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# QObject::moveToThread: Current thread (0x8670f30) is not the object's thread (0x8198ce0).
# Cannot move to target thread (0x8670f30)
#
# ...

# %%
import cv2
import numpy as np
img = np.zeros((512,512,3),dtype="uint8") + 255
cv2.circle(img,(256,256),40,(255,0,0),-1)

img2 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)


cv2.imshow("BGR",img)
cv2.imshow("RGB",img2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ...
# QObject::moveToThread: Current thread (0x1e5447f0) is not the object's thread (0x1e5cdcb0).
# Cannot move to target thread (0x1e5447f0)
#
# QObject::moveToThread: Current thread (0x1e5447f0) is not the object's thread (0x1e5cdcb0).
# Cannot move to target thread (0x1e5447f0)
#
# Qt: Session management error: Could not open network socket
# QObject::moveToThread: Current thread (0x1e5447f0) is not the object's thread (0x1e5cdcb0).
# Cannot move to target thread (0x1e5447f0)
#
# QObject::moveToThread: Current thread (0x1e5447f0) is not the object's thread (0x1e5cdcb0).
# Cannot move to target thread (0x1e5447f0)
#
# QObject::moveToThread: Current thread (0x1e5447f0) is not the object's thread (0x1e5cdcb0).
# Cannot move to target thread (0x1e5447f0)
#
# QObject::moveToThread: Current thread (0x1e5447f0) is not the object's thread (0x1e5cdcb0).
# Cannot move to target thread (0x1e5447f0)
#
# QObject::moveToThread: Current thread (0x1e5447f0) is not the object's thread (0x1e5cdcb0).
# ...

# %%
import cv2

cap = cv2.VideoCapture(0)
while True:
    ret,frame = cap.read()
    frame = cv2.flip(frame,1)
    frame = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    cv2.imshow("Webcam",frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
cv2.destroyAllWindows()
# Out:
# ...
# QObject::moveToThread: Current thread (0x59ed770) is not the object's thread (0x593deb0).
# Cannot move to target thread (0x59ed770)
#
# QObject::moveToThread: Current thread (0x59ed770) is not the object's thread (0x593deb0).
# Cannot move to target thread (0x59ed770)
#
# Qt: Session management error: Could not open network socket
# QObject::moveToThread: Current thread (0x59ed770) is not the object's thread (0x593deb0).
# Cannot move to target thread (0x59ed770)
#
# QObject::moveToThread: Current thread (0x59ed770) is not the object's thread (0x593deb0).
# Cannot move to target thread (0x59ed770)
#
# QObject::moveToThread: Current thread (0x59ed770) is not the object's thread (0x593deb0).
# Cannot move to target thread (0x59ed770)
#
# QObject::moveToThread: Current thread (0x59ed770) is not the object's thread (0x593deb0).
# Cannot move to target thread (0x59ed770)
#
# QObject::moveToThread: Current thread (0x59ed770) is not the object's thread (0x593deb0).
# ...

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)


def nothing(x):
    pass

cv2.namedWindow("Trackbar") 
cv2.resizeWindow("Trackbar",500,500)

cv2.createTrackbar("Lower - H", "Trackbar", 0,180, nothing)
cv2.createTrackbar("Lower - S","Trackbar",0,255, nothing)
cv2.createTrackbar("Lower - V","Trackbar", 0,255, nothing)



cv2.createTrackbar("Upper - H", "Trackbar", 0, 180, nothing)
cv2.createTrackbar("Upper - S","Trackbar", 0,255, nothing)
cv2.createTrackbar("Upper - V","Trackbar", 0,255 , nothing)

cv2.setTrackbarPos("Upper - H","Trackbar",180)
cv2.setTrackbarPos("Upper - S","Trackbar",255)
cv2.setTrackbarPos("Upper - V","Trackbar",255)

while True:
    ret,frame = cap.read()
   
    frame = cv2.flip(frame,1)
    frame_2 = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)

    lower_h = cv2.getTrackbarPos("Lower - H","Trackbar")
    lower_s = cv2.getTrackbarPos("Lower - S","Trackbar")
    lower_v = cv2.getTrackbarPos("Lower - H","Trackbar")

    upper_h = cv2.getTrackbarPos("Upper - H","Trackbar")
    upper_s = cv2.getTrackbarPos("Upper - S","Trackbar")
    upper_v = cv2.getTrackbarPos("Upper - V","Trackbar")

    lower_color = np.array([lower_h,lower_s,lower_v])
    upper_color = np.array([upper_h,upper_s,upper_v])

    mask = cv2.inRange(frame_2,lower_color,upper_color)

    cv2.imshow("Webcam",frame)
    cv2.imshow("HSV",mask)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2a8c0e70) is not the object's thread (0x2af6e790).
# Cannot move to target thread (0x2a8c0e70)
#
# QObject::moveToThread: Current thread (0x2a8c0e70) is not the object's thread (0x2af6e790).
# Cannot move to target thread (0x2a8c0e70)
#
# QObject::moveToThread: Current thread (0x2a8c0e70) is not the object's thread (0x2af6e790).
# Cannot move to target thread (0x2a8c0e70)
#
# QObject::moveToThread: Current thread (0x2a8c0e70) is not the object's thread (0x2af6e790).
# Cannot move to target thread (0x2a8c0e70)
#
# QObject::moveToThread: Current thread (0x2a8c0e70) is not the object's thread (0x2af6e790).
# Cannot move to target thread (0x2a8c0e70)
#
# QObject::moveToThread: Current thread (0x2a8c0e70) is not the object's thread (0x2af6e790).
# Cannot move to target thread (0x2a8c0e70)
#
# QObject::moveToThread: Current thread (0x2a8c0e70) is not the object's thread (0x2af6e790).
# Cannot move to target thread (0x2a8c0e70)
#
# ...
