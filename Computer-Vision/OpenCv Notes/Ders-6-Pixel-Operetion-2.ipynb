# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("test_image/foto2.jpeg")
cv2.imshow("Image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ...
# QObject::moveToThread: Current thread (0x1d0d7f90) is not the object's thread (0x1df4c250).
# Cannot move to target thread (0x1d0d7f90)
#
# QObject::moveToThread: Current thread (0x1d0d7f90) is not the object's thread (0x1df4c250).
# Cannot move to target thread (0x1d0d7f90)
#
# Qt: Session management error: Could not open network socket
# QObject::moveToThread: Current thread (0x1d0d7f90) is not the object's thread (0x1df4c250).
# Cannot move to target thread (0x1d0d7f90)
#
# QObject::moveToThread: Current thread (0x1d0d7f90) is not the object's thread (0x1df4c250).
# Cannot move to target thread (0x1d0d7f90)
#
# QObject::moveToThread: Current thread (0x1d0d7f90) is not the object's thread (0x1df4c250).
# Cannot move to target thread (0x1d0d7f90)
#
# QObject::moveToThread: Current thread (0x1d0d7f90) is not the object's thread (0x1df4c250).
# Cannot move to target thread (0x1d0d7f90)
#
# QObject::moveToThread: Current thread (0x1d0d7f90) is not the object's thread (0x1df4c250).
# ...

# %%
img = cv2.imread("test_image/foto2.jpeg")
corner = img[0:500,0:500]
cv2.imshow("Corner",corner)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# ...

# %%
img = cv2.imread("test_image/foto2.jpeg")
img[0:500,0:500]=(1,1,1)
cv2.imshow("Corner",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# QObject::moveToThread: Current thread (0x262eb7f0) is not the object's thread (0x2597c740).
# Cannot move to target thread (0x262eb7f0)
#
# ...

# %%
import cv2
path = "test_image/foto1.jpeg"
img=cv2.imread(path) 
print(img.shape)

# 3. Değer derinlik değeri foto siyah beyaz olsaydı default 0 olurdu
cv2.imshow("Image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (375, 300, 3)
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# ...

# %%
import cv2

path = "test_image/foto1.jpeg"
img = cv2.imread(path,0)

print(img.shape) # 0 ise gözükmez zaten derinlik
# ilk değer yükseklik ikinci değer en üçünçü değer derinlikn
# height width channel
print(img.size) # heightxwidthxchannel
print(img.shape[0]*img.shape[1])
cv2.imshow("Image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (375, 300)
# 112500
# 112500
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# Cannot move to target thread (0x16e48820)
#
# QObject::moveToThread: Current thread (0x16e48820) is not the object's thread (0x1759e250).
# ...

# %%
# ROI: Region of interest (İlgilendiğim alan)
